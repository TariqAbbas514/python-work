# %% [markdown]
# # Tuples and Sets

# %%
#Tuples and sets
lsit = ["a", "b"]  # list
list1 = ("a", "b") # tuples
set = {"a", "b"}   # sets

print(list)
# Out:
# <class 'list'>

# %%
print(list1)
# Out:
# ('a', 'b')

# %%
print(set)
# Out:
# {'a', 'b'}

# %%
thistuple = ("apple", "mango", "banana")
print(thistuple)
# Out:
# ('apple', 'mango', 'banana')

# %%
thistuple = ("apple", "mango", "banana", "orange", "lemon")
print(thistuple[1:3])
# Out:
# ('mango', 'banana')

# %%
print(thistuple[1])
# Out:
# mango

# %%
print(thistuple[-4:-1])
# Out:
# ('mango', 'banana', 'orange')

# %%
thistuple = ("apple", "mango", "banana")
for x in thistuple:
 print(x)
# Out:
# apple
# mango
# banana

# %%
thistuple = ("apple", "mango", "banana")
print(len(thistuple))
# Out:
# 3

# %% [markdown]
# # If/Else

# %%
#11.If else
a = 450
b = 100
if a > b:
  print("b is less than a")
# Out:
# b is less than a

# %%
a = 44
b = 44
if b > a:
  print("b is greater than a")
elif a==b:
  print("a and b are equal")
# Out:
# a and b are equal

# %%
a = 200
b = 33
if b > a:
  print("b is greater than a")
elif a==b:
  print("a and b are equal")
else:
  print("b is less than a")
# Out:
# b is less than a

# %%
a = 200
b = 33
if a==b:
  print("a is equal to b")
elif a!=b:
  print("a and b are not equal")
# Out:
# a and b are not equal

# %% [markdown]
# # While Loops

# %%
#while loops
mango = 1
while mango < 6:
  print(mango)
  mango += 1
# Out:
# 1
# 2
# 3
# 4
# 5
